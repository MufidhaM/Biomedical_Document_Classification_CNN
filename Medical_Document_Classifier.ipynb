# %% [markdown]
# # Title: AIDI 1002 Final Report Biomedical Document Classification CNN
#
#     Mohideen Munas Mufidha Banu
# #### MufidhaBanu.MohideenMunas@mygeorgian.ca

# %% [markdown]
# # Introduction:
#
# #### Problem Description:
#
# The paper presents an evaluation of several machine learning algorithms, including Naive Bayes, Decision Tree, Random Forest, Support Vector Machine, and K-Nearest Neighbors, for classifying biomedical documents into different categories.
#
# The authors use the PubMed Central Open Access Subset dataset for their experiments and evaluate the performance of each algorithm in terms of accuracy, precision, recall, F1-score, and area under the receiver operating characteristic (ROC) curve.
#
# #### Context of the Problem:
#
# The classification of biomedical documents into different categories is an important problem in the field of biomedical research. With the ever-increasing amount of biomedical literature being published, it is becoming increasingly difficult for researchers to stay up-to-date with the latest developments in their respective fields. Therefore, the automatic classification of biomedical documents can greatly aid in the efficient and effective organization and retrieval of information, making it easier for researchers to stay informed and up-to-date on the latest findings. Additionally, accurate and efficient classification of biomedical documents can help accelerate the discovery and development of new treatments and therapies, ultimately leading to improved healthcare outcomes for patients.
#
# #### Limitation About other Approaches:
#
# Previous approaches for classifying biomedical documents have been limited by factors such as reliance on manual feature engineering and a lack of comprehensive evaluation across multiple machine learning algorithms.
#
#
# #### Solution:
#
# Naive Bayes, Decision Tree, Random Forest, Support Vector Machine, and K-Nearest Neighbors are commonly used algorithms that is been used by the authors in this research paper, recent advances in machine learning such as deep learning approaches such as Convolutional Neural Networks (CNNs) and Recurrent Neural Networks (RNNs) could potentially outperform these traditional algorithms.
#
# And I will be experimenting with CNNs to prove this.
# CNN networks are able to automatically learn features from raw input data, such as images or text, without the need for manual feature engineering. This makes them well-suited for text classification tasks, as they can automatically learn relevant features from the text data and make accurate predictions.

# %% [markdown]
# # Background
#
# While the paper "Performance evaluation of Machine learning algorithms in Biomedical Document Classification" by B. Dash et al. provides a useful evaluation of different machine learning algorithms for document classification tasks in the biomedical domain, it also has a few limitations.
#
# One limitation is the use of a single dataset, the PubMed Central Open Access Subset, for their experiments. While this dataset is commonly used in the biomedical domain for document classification tasks, it is limited in terms of size and variety. Future work could explore the performance of these algorithms on other biomedical datasets with different characteristics, to better generalize the findings.
#
# **Another limitation is the use of only basic machine learning algorithms such as Naive Bayes, Decision Tree, Random Forest, Support Vector Machine, and K-Nearest Neighbors.**
#
# Additionally, the paper does not explore the impact of hyperparameters on the performance of the machine learning algorithms. Tuning the hyperparameters of the algorithms can often lead to improved performance. Future work could explore the effect of different hyperparameters on the performance of the algorithms for biomedical document classification.
#
# Finally, the paper does not provide an analysis of the features used for classification. Feature selection and engineering can often play a crucial role in the performance of machine learning algorithms. Future research could explore the impact of different feature selection and engineering techniques on the performance of machine learning algorithms for biomedical document classification.
#
# | Reference |Explanation |  Dataset/Input |Weakness
# | --- | --- | --- | --- |
# | B. Dash et al. [1] | They used Naive Bayes, Decision Tree, Random Forest, Support Vector Machine, and K-Nearest Neighbors, for classifying biomedical documents into different categories.| PubMed Central Open Access Subset dataset | the best testing accuracy achieved by any of the algorithms is 60.03% by the Random Forest algorithm.

# %% [markdown]
# # Methodology
#
# The paper "Performance evaluation of Machine learning algorithms in Biomedical Document Classification" by B. Dash et al. uses a supervised machine learning approach for document classification in the biomedical domain. The methodology can be summarized as follows:
#
# **Data collection**: The PubMed Central Open Access Subset dataset is downloaded from the National Library of Medicine website. This dataset contains full-text articles from biomedical journals in the XML format.
#
# **Data preprocessing**: The XML files are preprocessed using the preprocess.py script. This script converts the XML files to plain text files and performs text preprocessing steps such as tokenization, stopword removal, and stemming. The preprocessed files are saved in the processed_data directory.
#
# **Data splitting**: The preprocessed files are randomly split into training and testing sets in a 70:30 ratio using the train_test_split.py script.
#
# **Feature extraction**: Features are extracted from the preprocessed text using the Term Frequency-Inverse Document Frequency (TF-IDF) approach. This approach measures the importance of a term in a document by weighing the frequency of the term by the inverse document frequency.
#
# **Model training**: Several machine learning models are trained on the training set using the scikit-learn library. The models include Naive Bayes, Decision Tree, Random Forest, Support Vector Machine, and K-Nearest Neighbors.
#
# **Model evaluation**: The trained models are evaluated on the testing set using metrics such as accuracy, precision, recall, F1-score, and area under the receiver operating characteristic curve (AUC-ROC).
#
# **Results analysis**: The results are analyzed to determine the performance of each algorithm on the biomedical document classification task.
#
# Overall, this methodology uses a standard machine learning approach for text classification, including preprocessing, feature extraction, and model training and evaluation. While the specific algorithms and techniques used in this paper may not be the most advanced or optimal for the task, the methodology provides a useful baseline for comparing the performance of different algorithms on biomedical document classification tasks.
#
# **My implementation:**
#
# One of the limitations is the use of only basic machine learning algorithms such as Naive Bayes, Decision Tree, Random Forest, Support Vector Machine, and K-Nearest Neighbors.
#
# While these are commonly used algorithms, recent advances in machine learning such as deep learning approaches such as Convolutional Neural Networks (CNNs) and Recurrent Neural Networks (RNNs) could potentially outperform these traditional algorithms.
# Future research could explore the use of these more advanced machine learning techniques for biomedical document classification.
# And I will be experimenting with CNNs to prove this.

# %% [markdown]
# # Implementation

# %% [markdown]
# The dataset used in the paper "Performance evaluation of Machine learning algorithms in Biomedical Document Classification" by Bichitrananda et al is named "BC3_part1.csv" and contains a total of 13918 rows and 3 columns.
# The columns represent:
# Label: The class label for each document. In this case, there are 5 classes: Background, Objective, Methods, Results, and Conclusions.
# Title: The title of the document.
# Abstract: The abstract of the document.
# The dataset was created by selecting 500 documents randomly from each of the 5 classes from the BC3 corpus, resulting in a total of 2500 documents.

# %%
import numpy as np
import sklearn
from sklearn.datasets import load_files
import sys
from time import time
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn import tree
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn import metrics
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\mufid\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
#Data description
df2=pd.read_csv('BC3_part1.csv')
df2.head()
# Out:
#        PMID  Label Journal Title ISO Abbreviation     NLM ID  Year  \
# 0  17502104      1             Plant Signal Behav  101291431  2009
# 1  17503969      1             Plant Signal Behav  101291431  2009
# 2  17505518      1             Plant Signal Behav  101291431  2009
# 3  17510629      1             Plant Signal Behav  101291431  2009
# 4  17511879      1             Plant Signal Behav  101291431  2009
#
#                                                Title  \
# 0  Plant caspase-like proteases in plant programm...
# 1  The ER body, a new organelle in Arabidopsis th...
# 2  Biomechanics of climbing palms and how they cl...
# 3  Intracellular Ca2+ stores could participate to...
# 4  Carbon and nitrogen nutrient balance signaling...
#
#                                             Abstract
# 0  Programmed cell death (PCD) is a genetically-c...
# 1  Plants develop various ER-derived structures w...
# 2  Climbing plants have fascinated botanists sinc...
# ...

# %%
df2.groupby('Label').size()
# Out:
# Label
# 0    1140
# 1    1140
# dtype: int64

# %%
#sentences=df2['Abstract']
#labels=df2['Label']
#split the data into train and test dataset
#print(len(sentences))
train_data=df2['Abstract']
Y=df2['Label']
print(len(train_data))
bbc_vec = CountVectorizer(min_df=2, tokenizer=nltk.word_tokenize, encoding='latin-1')
bbc_counts = bbc_vec.fit_transform(train_data.values.astype('U'))
tfidf_transformer = TfidfTransformer()
X = tfidf_transformer.fit_transform(bbc_counts)
print(X.shape)
# Out:
# 2280
# (2280, 11964)

# %%
#from sklearn.model_selection import StratifiedKFold
#kfold = StratifiedKFold(n_splits=10, random_state=7)

# %% [markdown]
# **Comparision of Algorithms**

# %%
#Comparision of Algorithms
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from matplotlib import pyplot
from sklearn import svm
# prepare models
models = []
models.append(('KNN', KNeighborsClassifier(n_neighbors=10)))
models.append(('DT', tree.DecisionTreeClassifier()))
#models.append(('KNN', KNeighborsClassifier()))
models.append(('MNB', MultinomialNB(alpha=.01)))
models.append(('BNB', BernoulliNB(alpha=.01)))
models.append(('RF', RandomForestClassifier(n_estimators=100)))
models.append(('SVM', svm.SVC()))
models.append(('PPN', Perceptron(max_iter=50, tol=1e-3)))
models.append(('SGD', SGDClassifier(alpha=.0001, max_iter=50,penalty="l1")))
models.append(('Ridge', RidgeClassifier(tol=1e-2, solver="sag")))
models.append(('RC', NearestCentroid()))
models.append(('PA', PassiveAggressiveClassifier(max_iter=50, tol=1e-3)))
models.append(('BPN', MLPClassifier()))


# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
  kfold = StratifiedKFold(n_splits=10)
  cv_results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
  results.append(cv_results)
  names.append(name)
  msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
  print(msg)
# boxplot algorithm comparison
fig = pyplot.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()
# Out:
# C:\Users\mufid\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# **Evaluationg Accuracy, precision, recall, f1-score for all algorithms.**

# %% [markdown]
# **SVM**

# %%
#.................SVM................
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
acc=list();
prec=list();
recall=list();
f1=list();
from sklearn import svm
from sklearn.model_selection import StratifiedKFold as SKF
skf = SKF(n_splits=5)
model = svm.SVC()
for train_index, test_index in skf.split(X,Y):
  #print('TRAIN', train_index, “TEST:”, test_index);
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
  model.fit(X_train, y_train)
  y_pred=model.predict(X_test)
  #y_pred=FRS(X_train,y_train,X_test,0.15)
  score=accuracy_score(y_test, y_pred)
  acc.append(score)
  score1=precision_score(y_test, y_pred, average='weighted')
  prec.append(score1)
  score2=recall_score(y_test, y_pred, average='weighted')
  recall.append(score2)
  score3=f1_score(y_test, y_pred, average='weighted')  
  f1.append(score3)

a = np.array(acc)
print("Accuracy:",a.mean(), a.std())
b = np.array(prec)
print("Precision:",b.mean(), b.std())
c = np.array(recall)
print("Recall:",c.mean(), c.std())
d = np.array(f1)
print("F1-score:",d.mean(), d.std())
# Out:
# Accuracy: 0.6017543859649124 0.09886046637997163
# Precision: 0.6141775568028158 0.10337406429288602
# Recall: 0.6017543859649124 0.09886046637997163
# F1-score: 0.5797185225534893 0.11372274513826665

# %%
a = np.array(acc)
print("Accuracy:",a.mean(), a.std())
b = np.array(prec)
print("Precision:",b.mean(), b.std())
c = np.array(recall)
print("Recall:",c.mean(), c.std())
d = np.array(f1)
print("F1-score:",d.mean(), d.std())
# Out:
# Accuracy: 0.6035087719298246 0.07231124801661162
# Precision: 0.6159083986672369 0.08152371299604218
# Recall: 0.6035087719298246 0.07231124801661162
# F1-score: 0.5844896093272972 0.08703679376933351

# %%
#.....................SVM.....................
from sklearn import svm
from sklearn.model_selection import cross_validate
model = svm.SVC()
#model = LogisticRegression()
#precision_score
scoring = ['accuracy','precision','recall','f1_weighted']
#results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
results = cross_validate(model, X, Y, cv=kfold, scoring=scoring)
print("Accuracy=",results["test_accuracy"].mean(),results["test_accuracy"].std())
print("F1_score=",results["test_f1_weighted"].mean(),results["test_f1_weighted"].std())
print("Precision=",results["test_precision"].mean(),results["test_precision"].std())
print("Recall=",results["test_recall"].mean(),results["test_recall"].std())
# Out:
# Accuracy= 0.6087719298245615 0.11443586792188894
# F1_score= 0.5863851428565168 0.13163154424687556
# Precision= 0.6498166767681712 0.13074217713982272
# Recall= 0.625438596491228 0.17913002373901457

# %% [markdown]
# **KNN**

# %%
#.................KNN................
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
acc=list();
prec=list();
recall=list();
f1=list();
from sklearn import svm
from sklearn.model_selection import StratifiedKFold as SKF
skf = SKF(n_splits=5)
model = KNeighborsClassifier(n_neighbors=10)
for train_index, test_index in skf.split(X,Y):
  #print('TRAIN', train_index, “TEST:”, test_index);
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
  model.fit(X_train, y_train)
  y_pred=model.predict(X_test)
  #y_pred=FRS(X_train,y_train,X_test,0.15)
  score=accuracy_score(y_test, y_pred)
  acc.append(score)
  score1=precision_score(y_test, y_pred, average='weighted')
  prec.append(score1)
  score2=recall_score(y_test, y_pred, average='weighted')
  recall.append(score2)
  score3=f1_score(y_test, y_pred, average='weighted')  
  f1.append(score3)

a = np.array(acc)
print("Accuracy:",a.mean(), a.std())
b = np.array(prec)
print("Precision:",b.mean(), b.std())
c = np.array(recall)
print("Recall:",c.mean(), c.std())
d = np.array(f1)
print("F1-score:",d.mean(), d.std())
# Out:
# C:\Users\mufid\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
#...................KNN............
from sklearn import svm
from sklearn.model_selection import cross_validate
model = KNeighborsClassifier(n_neighbors=10)
scoring = ['accuracy','precision','recall','f1_weighted']
#results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
results = cross_validate(model, X, Y, cv=kfold, scoring=scoring)
#print("Accuracy: %.3f (%.3f)") % (results.mean(), results.std())
print("Accuracy=",results["test_accuracy"].mean(),results["test_accuracy"].std())
print("F1_score=",results["test_f1_weighted"].mean(),results["test_f1_weighted"].std())
print("Precision=",results["test_precision"].mean(),results["test_precision"].std())
print("Recall=",results["test_recall"].mean(),results["test_recall"].std())
# Out:
# C:\Users\mufid\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# **Decision Tree Classifier**

# %%
#.................DT................
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
acc=list();
prec=list();
recall=list();
f1=list();
from sklearn.model_selection import StratifiedKFold as SKF
skf = SKF(n_splits=5)
from sklearn import tree
model = tree.DecisionTreeClassifier()
for train_index, test_index in skf.split(X,Y):
  #print('TRAIN', train_index, “TEST:”, test_index);
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
  model.fit(X_train, y_train)
  y_pred=model.predict(X_test)
  #y_pred=FRS(X_train,y_train,X_test,0.15)
  score=accuracy_score(y_test, y_pred)
  acc.append(score)
  score1=precision_score(y_test, y_pred, average='weighted')
  prec.append(score1)
  score2=recall_score(y_test, y_pred, average='weighted')
  recall.append(score2)
  score3=f1_score(y_test, y_pred, average='weighted')  
  f1.append(score3)

a = np.array(acc)
print("Accuracy:",a.mean(), a.std())
b = np.array(prec)
print("Precision:",b.mean(), b.std())
c = np.array(recall)
print("Recall:",c.mean(), c.std())
d = np.array(f1)
print("F1-score:",d.mean(), d.std())
# Out:
# Accuracy: 0.5407894736842105 0.04843662348167903
# Precision: 0.5411755346730516 0.049032856293083224
# Recall: 0.5407894736842105 0.04843662348167903
# F1-score: 0.53724099153736 0.05074613316920719

# %% [markdown]
# **Random Forest Classifier**

# %%
#.................RF................
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
acc=list();
prec=list();
recall=list();
f1=list();
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100)
from sklearn.model_selection import StratifiedKFold as SKF
skf = SKF(n_splits=5)
for train_index, test_index in skf.split(X,Y):
  #print('TRAIN', train_index, “TEST:”, test_index);
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
  model.fit(X_train, y_train)
  y_pred=model.predict(X_test)
  #y_pred=FRS(X_train,y_train,X_test,0.15)
  score=accuracy_score(y_test, y_pred)
  acc.append(score)
  score1=precision_score(y_test, y_pred, average='weighted')
  prec.append(score1)
  score2=recall_score(y_test, y_pred, average='weighted')
  recall.append(score2)
  score3=f1_score(y_test, y_pred, average='weighted')  
  f1.append(score3)

a = np.array(acc)
print("Accuracy:",a.mean(), a.std())
b = np.array(prec)
print("Precision:",b.mean(), b.std())
c = np.array(recall)
print("Recall:",c.mean(), c.std())
d = np.array(f1)
print("F1-score:",d.mean(), d.std())
# Out:
# Accuracy: 0.6057017543859649 0.10781269166973027
# Precision: 0.6213767483094905 0.10948629730431514
# Recall: 0.6057017543859649 0.10781269166973027
# F1-score: 0.5848300713670478 0.12053139040510848

# %% [markdown]
# **Multinomial NB**

# %%
from sklearn.model_selection import StratifiedKFold as SKF
skf = SKF(n_splits=5)

# %%
#.................MNB................
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
acc=list();
prec=list();
recall=list();
f1=list();
from sklearn.model_selection import StratifiedKFold as SKF
skf = SKF(n_splits=5)
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
model = MultinomialNB(alpha=.01)
for train_index, test_index in skf.split(X,Y):
  #print('TRAIN', train_index, “TEST:”, test_index);
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
  model.fit(X_train, y_train)
  y_pred=model.predict(X_test)
  #y_pred=FRS(X_train,y_train,X_test,0.15)
  score=accuracy_score(y_test, y_pred)
  acc.append(score)
  score1=precision_score(y_test, y_pred, average='weighted')
  prec.append(score1)
  score2=recall_score(y_test, y_pred, average='weighted')
  recall.append(score2)
  score3=f1_score(y_test, y_pred, average='weighted')  
  f1.append(score3)

a = np.array(acc)
print("Accuracy:",a.mean(), a.std())
b = np.array(prec)
print("Precision:",b.mean(), b.std())
c = np.array(recall)
print("Recall:",c.mean(), c.std())
d = np.array(f1)
print("F1-score:",d.mean(), d.std())
# Out:
# Accuracy: 0.5688596491228071 0.05911460716733101
# Precision: 0.5736153850540353 0.060444986692860254
# Recall: 0.5688596491228071 0.05911460716733101
# F1-score: 0.5558861372142223 0.06749045278554983

# %% [markdown]
# **BernoulliNB**

# %%
#.................BNB................
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
acc=list();
prec=list();
recall=list();
f1=list();
from sklearn.model_selection import StratifiedKFold as SKF
skf = SKF(n_splits=5)
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
model = BernoulliNB(alpha=.01)
for train_index, test_index in skf.split(X,Y):
  #print('TRAIN', train_index, “TEST:”, test_index);
  X_train, X_test = X[train_index], X[test_index]
  y_train, y_test = Y[train_index], Y[test_index]
  model.fit(X_train, y_train)
  y_pred=model.predict(X_test)
  #y_pred=FRS(X_train,y_train,X_test,0.15)
  score=accuracy_score(y_test, y_pred)
  acc.append(score)
  score1=precision_score(y_test, y_pred, average='weighted')
  prec.append(score1)
  score2=recall_score(y_test, y_pred, average='weighted')
  recall.append(score2)
  score3=f1_score(y_test, y_pred, average='weighted')  
  f1.append(score3)

a = np.array(acc)
print("Accuracy:",a.mean(), a.std())
b = np.array(prec)
print("Precision:",b.mean(), b.std())
c = np.array(recall)
print("Recall:",c.mean(), c.std())
d = np.array(f1)
print("F1-score:",d.mean(), d.std())
# Out:
# Accuracy: 0.587280701754386 0.08439307698811015
# Precision: 0.5955984097877088 0.08735433417088587
# Recall: 0.587280701754386 0.08439307698811015
# F1-score: 0.5698790432476113 0.09550217215682556

# %%
#........................PPN..........
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.model_selection import cross_validate
model = Perceptron(max_iter=50, tol=1e-3)
scoring = ['accuracy','precision','recall','f1_weighted']
#results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
results = cross_validate(model, X, Y, cv=kfold, scoring=scoring)
#print("Accuracy: %.3f (%.3f)") % (results.mean(), results.std())
print("Accuracy=",results["test_accuracy"].mean(),results["test_accuracy"].std())
print("F1_score=",results["test_f1_weighted"].mean(),results["test_f1_weighted"].std())
print("Precision=",results["test_precision"].mean(),results["test_precision"].std())
print("Recall=",results["test_recall"].mean(),results["test_recall"].std())
# Out:
# Accuracy= 0.5548245614035088 0.057796634053997334
# F1_score= 0.5468467226910956 0.059443515236311195
# Precision= 0.5731295352687525 0.0706461474973502
# Recall= 0.5421052631578948 0.10114761617824261

# %% [markdown]
# **Ridge**

# %%
#........................Ridge..........
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.model_selection import cross_validate
model = RidgeClassifier(tol=1e-2, solver="sag")
scoring = ['accuracy','precision','recall','f1_weighted']
#results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
results = cross_validate(model, X, Y, cv=kfold, scoring=scoring)
#print("Accuracy: %.3f (%.3f)") % (results.mean(), results.std())
print("Accuracy=",results["test_accuracy"].mean(),results["test_accuracy"].std())
print("F1_score=",results["test_f1_weighted"].mean(),results["test_f1_weighted"].std())
print("Precision=",results["test_precision"].mean(),results["test_precision"].std())
print("Recall=",results["test_recall"].mean(),results["test_recall"].std())
# Out:
# C:\Users\mufid\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:729: UserWarning: "sag" solver requires many iterations to fit an intercept with sparse inputs. Either set the solver to "auto" or "sparse_cg", or set a low "tol" and a high "max_iter" (especially if inputs are not standardized).
#   warnings.warn(
# C:\Users\mufid\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:729: UserWarning: "sag" solver requires many iterations to fit an intercept with sparse inputs. Either set the solver to "auto" or "sparse_cg", or set a low "tol" and a high "max_iter" (especially if inputs are not standardized).
#   warnings.warn(
# C:\Users\mufid\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:729: UserWarning: "sag" solver requires many iterations to fit an intercept with sparse inputs. Either set the solver to "auto" or "sparse_cg", or set a low "tol" and a high "max_iter" (especially if inputs are not standardized).
#   warnings.warn(
# ...

# %% [markdown]
# **PassiveAggressiveClassifier**

# %%
#........................PA..........
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.model_selection import cross_validate
model = PassiveAggressiveClassifier(max_iter=50, tol=1e-3)
scoring = ['accuracy','precision','recall','f1_weighted']
#results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
results = cross_validate(model, X, Y, cv=kfold, scoring=scoring)
#print("Accuracy: %.3f (%.3f)") % (results.mean(), results.std())
print("Accuracy=",results["test_accuracy"].mean(),results["test_accuracy"].std())
print("F1_score=",results["test_f1_weighted"].mean(),results["test_f1_weighted"].std())
print("Precision=",results["test_precision"].mean(),results["test_precision"].std())
print("Recall=",results["test_recall"].mean(),results["test_recall"].std())
# Out:
# Accuracy= 0.5530701754385965 0.06271929824561404
# F1_score= 0.5457326283958085 0.06570246444824124
# Precision= 0.5705729737891464 0.07399794487452724
# Recall= 0.5526315789473685 0.07836039099693787

# %% [markdown]
# ![download%20%2820%29.png](attachment:download%20%2820%29.png)

# %% [markdown]
# The authors evaluated the performance of five machine learning algorithms, including Naive Bayes, Decision Tree, Random Forest, Support Vector Machine and K-Nearest Neighbors for classifying biomedical documents into different categories using the BC3-PL dataset.
#
# The RF model achieved the highest accuracy of 0.6035, outperforming the other models. The precision, recall, and F1-score of the RF model were also higher compared to the other models. The area under the ROC curve for the RF model was 0.988, indicating its excellent performance in distinguishing between positive and negative instances.
#
# The authors concluded that the RF model outperformed the other models in terms of accuracy and other evaluation metrics for classifying biomedical documents using the BC3-PL dataset. They also suggested that the RF model could be further optimized and applied to other similar classification tasks in the biomedical domain.

# %% [markdown]
# ![download%20%2822%29.png](attachment:download%20%2822%29.png)

# %% [markdown]
# # My Implementation:

# %% [markdown]
# # Deep neural network

# %% [markdown]
# I have used keras for setting up the deep neural network. It relies on highly dedicated or specialized tensor libraries: Theano and tensor flow 2.1. keras doesn’t handle tensor manipulation and differentiation. The embedding layer takes the precalculated integers, uses the embedding matrix of the pretrained vectors to assigns the dense vectors. This result is fed into flatten layer for sequential input. From there it is fed to dense layer. I have also used GlobalMaxPooling ID after the embedding. Thisreduces the sample size by choosing maximum value of all the features.

# %% [markdown]
# # Convolutional Neural Network (Covnets)

# %% [markdown]
# It is a specialized deep neural network to identify peculiar trends which is used to discern the most important information in a sentence. The hidden layers called convolutional layer starts with a sample of input features of the dimensions of kernel filters. The dot product between the patch and multiplied weights of filter is taken. I have used one dimensional CNN which is unaffected by translations i.e. it can understand patterns at different position. The patch of filters slide filter slide over embedding matrix and extracts a specific pattern of n-gram. So, the kernels keep covering larger part of document until it creates global summarization of features A max-pooling strategy to subsample the input using max function is applied after every convolutional layer. It has two uses – it provides fixed-length output and reduces output dimensionality of most important features. Such layers are stacked multiple times to improve mining of abstract information.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def train_model(classifier, X_train, y_train, X_test, y_test, is_neural_net=False):
    # fit the training dataset on the classifier
    classifier.fit(X_train, y_train)
    # predict the labels on validation dataset
    predictions = classifier.predict(X_test)
    return metrics.accuracy_score(predictions, y_test)

# %%
# Deep Neural networks CNN
model = models.Sequential()
model.add(layers.Embedding(input_dim=vocab_size, 
                           output_dim=embedding_dim,
                           weights=[embedding_matrix],
                           input_length=maxlen,
                           trainable=True))
model.add(layers.SpatialDropout1D(0.3))
model.add(layers.Conv1D(128, 5, activation='relu'))
model.add(layers.GlobalMaxPool1D())
model.add(layers.Dense(256))
model.add(layers.Activation('relu'))
model.add(layers.Dropout(0.25))
model.add(layers.Dense(4))
model.add(layers.Activation('softmax'))
# model.summary()
 
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
 
history = model.fit(X_train_token, y_train_bi,
                    batch_size=30,
                    epochs=10,
                    validation_split=0.1,
                    verbose=1)

loss, accuracy = model.evaluate(X_train_token, y_train_bi, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test_token, y_test_bi, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# C:\Users\mufid\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# **Saving Model**
#
# Save the model as well as tokenizer.
# The tokenizer has to be saved because it is the vocabulary. The same tokenizer and vocabulary have to be used for accurate prediction.

# %%
# creates a HDF5 file 'my_model.h5'
model.model.save('save/my_model.h5')

# Save Tokenizer i.e. Vocabulary
with open('save/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Result

# %% [markdown]
# CNN gave the best performance on the test data with an accuracy of 90.87 % with 10 epochs. The model can be used to process any document and predict a class for it. Using some random news bio medical articles on the internet I found the predictions fairly correct.

# %% [markdown]
# **For Live Testing**
# Loading the CNN model

# %%
final_model = models.load_model('save/my_model.h5')
 
# load tokenizer
tokenizer = text.Tokenizer()
with open('save/tokenizer.pickle', 'rb') as handle:
    tokenizer = pickle.load(handle)

# %% [markdown]
# # Conclusion and Future Direction

# %% [markdown]
# While the classical models provided a good accuracy the neural network model improved it further. With more data the deep learning models will outmatch classical models.
#
# For future work more neural networks can be tested specially RNN and compare its performance with CNN.And in the future, the study can be extended by evaluating the performance of the CNN model on other biomedical datasets and exploring the hyperparameters of the model to improve its performance further. Additionally, it would be interesting to compare the performance of the CNN model with other deep learning models such as recurrent neural networks and transformers. Overall, this study demonstrates the potential of using deep learning models for classifying biomedical documents and the need for further research in this area.

# %% [markdown]
# # References:
#
# [1]:  Authors Bichitrananda Biswal,Sachi Nandan Mohanty, Performance evaluation of machine learning algorithms in biomedical document classification: a systematic review,  International Conference on Computing, Communication and Networking Technologies (ICCCNT),2019, 1-6
